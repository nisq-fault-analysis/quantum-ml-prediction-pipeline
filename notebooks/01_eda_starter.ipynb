# %% [markdown]
# # Starter EDA Notebook
#
# This notebook is intentionally thin. The idea is to keep reusable logic in `src/` and use the notebook for inspection, notes, and hypothesis generation.
#
# TODO: Update the dataset path and column names in `../experiments/configs/baseline.yaml` before running the cells below.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.config.io import load_config
from src.data.dataset import prepare_research_table, read_tabular_dataset
from src.features.gate_sequence import engineer_gate_sequence_features

# %%
config = load_config(Path("../experiments/configs/baseline.yaml"))
dataset = prepare_research_table(read_tabular_dataset(config.data), config.data)
dataset.head()

# %%
dataset[config.data.label_column].astype(str).value_counts().head(10)

# %%
feature_table = engineer_gate_sequence_features(
    frame=dataset,
    sequence_column=config.data.gate_sequence_column,
    feature_config=config.features,
    qubit_count_column=config.data.qubit_count_column,
)
feature_table.head()
